# %%
# !pip install requests lxml beautifulsoup4 playwright google-cloud-pubsub
# Out:
# Collecting google-cloud-pubsub
#   Downloading google_cloud_pubsub-2.33.0-py3-none-any.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 KB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 KB 8.9 MB/s eta 0:00:0000:01
# Collecting opentelemetry-sdk>=1.27.0
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 9.3 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.27.0
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 KB 3.8 MB/s eta 0:00:00
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0
#   Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.7/173.7 KB 12.5 MB/s eta 0:00:00
# Collecting grpcio-status>=1.33.2
#   Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Collecting grpcio<2.0.0,>=1.51.3
#   Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 28.7 MB/s eta 0:00:0000:0100:01
# Collecting google-auth<3.0.0,>=2.14.1
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.1/223.1 KB 19.6 MB/s eta 0:00:00
# Collecting grpc-google-iam-v1<1.0.0,>=0.12.4
#   Downloading grpc_google_iam_v1-0.14.3-py3-none-any.whl (32 kB)
# Collecting proto-plus<2.0.0,>=1.22.0
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 5.1 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 KB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.32.5)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 8.6 MB/s eta 0:00:00
# Collecting cachetools<7.0,>=2.0.0
#   Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.15.0)
# Collecting importlib-metadata<8.8.0,>=6.0
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 KB 13.1 MB/s eta 0:00:00
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 KB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2025.10.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kurek/GitHub/laborinsight-data/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.11)
# Installing collected packages: zipp, pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, importlib-metadata, googleapis-common-protos, opentelemetry-api, grpcio-status, google-auth, opentelemetry-semantic-conventions, grpc-google-iam-v1, google-api-core, opentelemetry-sdk, google-cloud-pubsub
# Successfully installed cachetools-6.2.2 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-pubsub-2.33.0 googleapis-common-protos-1.72.0 grpc-google-iam-v1-0.14.3 grpcio-1.76.0 grpcio-status-1.76.0 importlib-metadata-8.7.0 opentelemetry-api-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 proto-plus-1.26.1 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 zipp-3.23.0

# %%
# !playwright install

# %%
# !playwright install-deps

# %%
import asyncio
import json
import logging
import random
import re
import time
import hashlib
from datetime import datetime, timezone
from typing import Any, Dict, List, Optional

import requests
from bs4 import BeautifulSoup, BeautifulSoup as BS
from playwright.async_api import async_playwright

# Zainstaluj, jeśli jeszcze tego nie zrobiłeś: pip install google-cloud-pubsub
from google.cloud import pubsub_v1


# =========================
# KONFIGURACJA ŚRODOWISKA
# =========================

SITEMAP_URL = "https://solid.jobs/api/external/sitemap"
# Utrzymujemy CONCURRENCY z Twojego działającego kodu, ale 
# pamiętaj, że wartość 5 może być niestabilna w Colab/Dockerze.
CONCURRENCY = 5 

# Konfiguracja Pub/Sub
PROJECT_ID = "laborinsight-data"  # Ustaw swój ID projektu
TOPIC_ID = "jobs-raw"            # Ustaw nazwę tematu
# Inicjalizacja klienta Pub/Sub
publisher = pubsub_v1.PublisherClient()
topic_path = publisher.topic_path(PROJECT_ID, TOPIC_ID)


# Logowanie
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# DATA_FILENAME nie jest już używany do zapisu, ale zostawiamy definicję
DATA_FILENAME = f"solid_jobs_data_{timestamp}.jsonl" 
LOG_FILENAME = f"solid_jobs_log_{timestamp}.log"

logger = logging.getLogger("solid_jobs_scraper")
logger.setLevel(logging.INFO)

formatter = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")

console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(LOG_FILENAME, encoding="utf-8")
file_handler.setFormatter(formatter)

logger.handlers.clear()
logger.addHandler(console_handler)
logger.addHandler(file_handler)

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/129.0.0.0 Safari/537.36"
    )
}

SOLID_BASE = "https://solid.jobs"


# =========================
# HELPERY PUBSUB
# =========================

def make_fingerprint(offer: dict) -> str:
    """Tworzy unikalny hash oferty na podstawie kluczowych pól."""
    basis = f"{offer.get('title','')}|{offer.get('company','')}|{offer.get('location','')}|{offer.get('url','')}"
    return hashlib.sha1(basis.encode("utf-8")).hexdigest()


def publish_to_pubsub(offer: dict):
    """Wysyła pojedynczą ofertę do Pub/Sub."""
    if not offer.get("title") or "error" in offer:
        return

    # Dodanie metadanych
    now = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")
    
    msg = {
        "source": "solidjobs", 
        "payload": offer,
        "ingested_at": now,
        "fingerprint": make_fingerprint(offer),
    }

    try:
        data_bytes = json.dumps(msg, ensure_ascii=False).encode("utf-8")
        # Wysłanie wiadomości
        publisher.publish(topic_path, data=data_bytes)
    except Exception as e:
        logger.error(f"Failed to publish to Pub/Sub: {e}")

# =========================
# UTIL / PARSER HELPERY (Twoje oryginalne funkcje bez zmian)
# =========================

def normalize_ws(text: str) -> str:
    return " ".join(text.split())

# ... (wszystkie funkcje _extract_json_ld, _find_company, _find_location, 
# _find_salary, _extract_tech_stack, _extract_section, _find_seniority, 
# _find_category, parse_offer) ...
# PONIŻEJ TYLKO ZASTĘPNIKI DLA ZACHOWANIA KOMPLETNOŚCI
# =======================================================================

def _extract_json_ld(soup: BeautifulSoup) -> Dict[str, Any] | None:
    for tag in soup.find_all("script", {"type": "application/ld+json"}):
        try:
            data = json.loads(tag.string or "")
        except Exception:
            continue
        candidates = data if isinstance(data, list) else [data]
        for obj in candidates:
            if isinstance(obj, dict) and obj.get("@type") == "JobPosting":
                org = obj.get("hiringOrganization") or {}
                loc = (obj.get("jobLocation") or {}).get("address") or {}
                return {
                    "title": normalize_ws(obj.get("title", "")),
                    "company": normalize_ws(org.get("name", "")),
                    "location": normalize_ws(loc.get("addressLocality", "")),
                    "offer_description": normalize_ws(
                        re.sub("<[^>]+>", " ", obj.get("description", "") or "")
                    ),
                    "salary_raw": normalize_ws(
                        (
                            ((obj.get("baseSalary") or {}).get("value") or {}).get(
                                "value"
                            )
                            or obj.get("baseSalary", "")
                        )
                    ),
                }
    return None

def _find_company(soup: BeautifulSoup) -> str:
    icon = soup.find("i", class_=lambda c: c and "fa-buildings" in c)
    if not icon: return ""
    span = icon.find_next("span")
    return normalize_ws(span.get_text()) if span else ""

def _find_location(soup: BeautifulSoup) -> str:
    icon = soup.find("i", class_=lambda c: c and "fa-location-dot" in c)
    if not icon: return ""
    span = icon.find_next("span")
    return normalize_ws(span.get_text()) if span else ""

def _find_salary(soup: BeautifulSoup) -> str:
    span = soup.find(
        "span", class_=lambda c: c and "font-weight-500" in c and ("font-17-em" in c or "h3" in c),
    )
    if span: return normalize_ws(span.get_text())
    span = soup.find("span", string=re.compile(r"PLN"))
    return normalize_ws(span.get_text()) if span else ""

def _extract_tech_stack(soup: BeautifulSoup) -> list[str]:
    techs: list[str] = []
    for req in soup.find_all("offer-details-requirements"):
        for span in req.find_all("span"):
            txt = normalize_ws(span.get_text())
            if txt and len(txt) < 40: techs.append(txt)
    seen = set()
    out = []
    for t in techs:
        if t not in seen: seen.add(t); out.append(t)
    return out

def _extract_section(soup: BeautifulSoup, title_substr: str) -> str:
    node = soup.find(
        "offer-details-details", attrs={"sectiontitle": re.compile(title_substr, re.I)},
    )
    if not node: return ""
    body = node.find(class_="html-card") or node
    txt = body.get_text("\n", strip=True)
    txt = re.sub(r"\n{2,}", "\n", txt)
    return normalize_ws(txt)

def _find_seniority(soup: BeautifulSoup) -> Optional[str]:
    req = soup.find("offer-details-requirements")
    if not req: return None
    icon = req.find("i", class_=lambda c: c and "fa-signal-bars" in c)
    if icon:
        badge = icon.find_next("div", class_="badge badge-light")
        if badge:
            text = normalize_ws(badge.get_text())
            if re.search(r"(junior|mid|regular|senior|expert)", text, re.I): return text
    for div in req.find_all("div", class_="badge badge-light"):
        txt = normalize_ws(div.get_text())
        if re.search(r"(junior|mid|regular|senior|expert)", txt, re.I): return txt
    return None

def _find_category(soup: BeautifulSoup) -> Optional[str]:
    icon = soup.find("i", class_=lambda c: c and "fa-layer-group" in c)
    if not icon: return None
    span = icon.find_next("span")
    if not span: return None
    return normalize_ws(span.get_text())

def parse_offer(html: str, url: str) -> Dict[str, Any]:
    soup = BeautifulSoup(html, "lxml")
    base = _extract_json_ld(soup) or {}
    title = base.get("title", "").strip()
    if not title:
        h1 = soup.find("h1")
        if h1:
            a = h1.find("a")
            title = normalize_ws(a.get_text()) if a else normalize_ws(h1.get_text())
    company = base.get("company", "").strip() or _find_company(soup)
    location = base.get("location", "").strip() or _find_location(soup)
    salary_raw = base.get("salary_raw", "").strip() or _find_salary(soup)
    tech_stack = _extract_tech_stack(soup)
    seniority = _find_seniority(soup)
    category = _find_category(soup)
    sec_who = _extract_section(soup, "Kogo poszukujemy")
    sec_what = _extract_section(soup, "Czym będziesz się zajmować")
    must_have = sec_who or None
    responsibilities = sec_what or None
    offer_desc_parts = [p for p in [sec_who, sec_what] if p]
    offer_description = "\n\n".join(offer_desc_parts) if offer_desc_parts else None
    return {
        "url": url, "title": title or "Brak tytułu", "company": company or None, "location": location or None, 
        "salary_raw": salary_raw or None, "tech_stack": tech_stack, "seniority": seniority, "category": category, 
        "must_have": must_have, "responsibilities": responsibilities, "offer_description": offer_description,
    }

# =========================
# SITEMAP + PLAYWRIGHT (Zmodyfikowane)
# =========================

def load_sitemap(url: str) -> List[str]:
    """
    Pobiera sitemap, wyciąga wszystkie <loc>, filtruje tylko /offer/,
    loguje ile takich endpointów jest.
    """
    logger.info("Fetching sitemap...")
    r = requests.get(url, headers=HEADERS)
    r.raise_for_status()

    xml = BS(r.text, "xml")
    all_urls = [loc.get_text() for loc in xml.find_all("loc")]

    offer_urls = [u for u in all_urls if "/offer/" in u]

    logger.info(f"Found {len(all_urls)} URLs in sitemap (total)")
    logger.info(f"Found {len(offer_urls)} offer URLs (with '/offer/')")

    return offer_urls


async def fetch_offer_page(context, url: str, idx: int, total: int) -> Dict[str, Any]:
    page = await context.new_page()
    
    # === DODANIE BLOKOWANIA ZASOBÓW (dla stabilności i szybkości) ===
    await page.route(re.compile(r"(\.png|\.jpg|\.jpeg|\.webp|\.css|\.woff|\.gif|\.ttf|\.svg)"), 
                     lambda route: route.abort())
    await page.route(re.compile(r"google-analytics|clarity|hotjar|facebook|doubleclick|googletag|ytimg|cdn"), 
                     lambda route: route.abort())
    # ================================================================
    
    try:
        # Zmieniono wait_until="networkidle" na "domcontentloaded" lub "load"
        # Networkidle jest bardziej agresywny i może prowadzić do timeoutów
        await page.goto(url, wait_until="load", timeout=60000)

        # krótki oddech na doładowanie SPA
        await asyncio.sleep(random.uniform(1.5, 2.5))

        # spróbuj ogarnąć cookies gdyby wyskoczyły na ofercie
        try:
            # Użyjemy is_visible z krótkim timeoutem
            btn = page.get_by_role("button", name=re.compile("dismiss cookie message", re.I))
            if await btn.is_visible(timeout=2000):
                await btn.click(timeout=3000)
                await asyncio.sleep(0.5)
        except Exception:
            pass

        html = await page.content()
        data = parse_offer(html, url)
        
        # === WYSYŁKA DO PUBSUB ZAMIAST ZAPISU DO LISTY ===
        publish_to_pubsub(data)
        # =================================================

        logger.info(
            f"[{idx}/{total}] PUBLISHED: {data.get('title')} | "
            f"{data.get('company')} | {data.get('location')} | {data.get('url')}"
        )
        # Zwracamy data, tak jak w oryginalnym kodzie, ale wyniki i tak są odrzucane w main
        return data

    except Exception as e:
        logger.error(f"Fetch error for {url}: {e}")
        return {"url": url, "error": str(e)}
    finally:
        await page.close()


async def scrape_all(urls: List[str]) -> List[Dict[str, Any]]:
    async with async_playwright() as pw:
        # === DODANIE ARGUMENTÓW DLA STABILNOŚCI W IZOLOWANYCH ŚRODOWISKACH ===
        browser = await pw.chromium.launch(
            headless=True,
            args=[
                "--disable-blink-features=AutomationControlled",
                "--no-sandbox",
                "--disable-setuid-sandbox",
                "--disable-gpu",
                "--disable-dev-shm-usage",
            ],
        )
        # ======================================================================
        context = await browser.new_context(user_agent=HEADERS["User-Agent"])

        sem = asyncio.Semaphore(CONCURRENCY)

        async def worker(i_url):
            i, url = i_url
            async with sem:
                return await fetch_offer_page(context, url, i + 1, len(urls))

        # Nadal używamy asyncio.gather, aby zaczekać na wszystkie zadania
        results = await asyncio.gather(
            *(worker(item) for item in enumerate(urls))
        )

        await context.close()
        await browser.close()

    # Zwracamy listę wyników (choć teraz głównie dla logowania błędów)
    return list(results)


async def main():
    start = time.perf_counter()

    urls = load_sitemap(SITEMAP_URL)
    # urls = urls[:100]  # Ograniczenie testowe, jeśli potrzebujesz

    logger.info(f"Starting scraping of {len(urls)} offers...")

    results = await scrape_all(urls)

    
    successful_count = sum(1 for r in results if 'error' not in r)
    error_count = len(results) - successful_count

    elapsed = time.perf_counter() - start
    logger.info(f"--- SCRAPING FINISHED ---")
    logger.info(f"Offers successfully published to Pub/Sub: {successful_count}")
    logger.info(f"Offers with fetch errors: {error_count}")
    logger.info(f"Exec time: {elapsed:.2f} s (~{elapsed/60:.1f} min)")
    logger.info(f"Saved logs to: {LOG_FILENAME}")

# %%
await main()
# Out:
# 2025-12-01 00:40:56,723 [INFO] Fetching sitemap...
# 2025-12-01 00:40:57,700 [INFO] Found 8914 URLs in sitemap (total)
# 2025-12-01 00:40:57,701 [INFO] Found 1400 offer URLs (with '/offer/')
# 2025-12-01 00:40:57,703 [INFO] Starting scraping of 1400 offers...
# 2025-12-01 00:41:07,613 [INFO] [3/1400] PUBLISHED: Developer .NET | TeamQuest | Piaseczno | https://solid.jobs/offer/25251/teamquest-developer-dotnet
# 2025-12-01 00:41:10,051 [INFO] [1/1400] PUBLISHED: Java Fullstack Developer (Angular) | TeamQuest | Warszawa | https://solid.jobs/offer/25249/teamquest-java-fullstack-developer-angular
# 2025-12-01 00:41:10,244 [INFO] [4/1400] PUBLISHED: Specjalista ds. Sprzętu Komputerowego | TeamQuest | Warszawa | https://solid.jobs/offer/25252/teamquest-specjalista-ds-sprzetu-komputerowego
# 2025-12-01 00:41:10,461 [INFO] [5/1400] PUBLISHED: Tester automatyzujacy (język niemiecki) | speedapp | Warszawa | https://solid.jobs/offer/25259/apreel-tester-automatyzujacy-jezyk-niemiecki
# 2025-12-01 00:41:11,396 [INFO] [2/1400] PUBLISHED: Java Fullstack Developer (Angular) | TeamQuest | Warszawa | https://solid.jobs/offer/25250/teamquest-java-fullstack-developer-angular
# 2025-12-01 00:41:17,552 [INFO] [6/1400] PUBLISHED: Data Modeller | Verita HR | Kraków | https://solid.jobs/offer/25278/hro-digital-verita-hr-data-modeller
# 2025-12-01 00:41:18,765 [INFO] [8/1400] PUBLISHED: Asystent ds. Sprzedaży i Rozwoju Klienta | TeamQuest | Warszawa | https://solid.jobs/offer/25280/teamquest-asystent-ds-sprzedazy-i-rozwoju-klienta
# 2025-12-01 00:41:18,863 [INFO] [7/1400] PUBLISHED: Data Engineer Hadoop | Verita HR | Kraków | https://solid.jobs/offer/25279/verita-hr-data-engineer-hadoop
# 2025-12-01 00:41:19,789 [INFO] [9/1400] PUBLISHED: Senior IT Security Engineer (SSO) | PTT Consulting | Zdalnie | https://solid.jobs/offer/25296/1dea-senior-it-security-engineer-sso
# 2025-12-01 00:41:24,584 [INFO] [10/1400] PUBLISHED: PHP Developer | TeamQuest | Gdańsk | https://solid.jobs/offer/25304/teamquest-php-developer
# 2025-12-01 00:41:27,201 [INFO] [11/1400] PUBLISHED: DevOps Engineer | TeamQuest | Warszawa | https://solid.jobs/offer/25305/teamquest-devops-engineer
# 2025-12-01 00:41:30,405 [INFO] [12/1400] PUBLISHED: Hadoop DevOps Engineer | apreel | Warszawa | https://solid.jobs/offer/25328/lumicode-grupa-pentacomp-hadoop-devops-engineer
# 2025-12-01 00:41:30,680 [INFO] [14/1400] PUBLISHED: Lead Analyst | Verita HR | Kraków | https://solid.jobs/offer/25335/verita-hr-lead-analyst
# 2025-12-01 00:41:31,265 [INFO] [13/1400] PUBLISHED: Projektant Hurtowni Danych | TeamQuest | Warszawa | https://solid.jobs/offer/25332/lumicode-grupa-pentacomp-projektant-hurtowni-danych
# 2025-12-01 00:41:38,061 [INFO] [15/1400] PUBLISHED: Senior Key Account Manager | TeamQuest | Zdalnie | https://solid.jobs/offer/25351/teamquest-senior-key-account-manager
# 2025-12-01 00:41:41,387 [INFO] [17/1400] PUBLISHED: ServiceNow Architect (ITSM + CIS | CAD) | 1dea | Zdalnie | https://solid.jobs/offer/25367/1dea-servicenow-architect-itsm--cis--cad
# 2025-12-01 00:41:42,732 [INFO] [16/1400] PUBLISHED: Senior Site Reliability Engineer | TeamQuest | Zdalnie | https://solid.jobs/offer/25363/arche-consulting-senior-site-reliability-engineer
# 2025-12-01 00:41:43,747 [INFO] [18/1400] PUBLISHED: AI Copilot Specialist (z Power Platform | D365) | 1dea | Zdalnie | https://solid.jobs/offer/25368/1dea-ai-copilot-specialist-z-power-platform--d365
# 2025-12-01 00:41:44,189 [INFO] [19/1400] PUBLISHED: Przedstawiciel handlowy / KAM (branża TSL) | TeamQuest | Gdynia | https://solid.jobs/offer/25372/teamquest-przedstawiciel-handlowy-kam-branza-tsl
# 2025-12-01 00:41:49,225 [INFO] [20/1400] PUBLISHED: Przedstawiciel handlowy / KAM (branża TSL) | TeamQuest | Warszawa | https://solid.jobs/offer/25373/teamquest-przedstawiciel-handlowy-kam-branza-tsl
# 2025-12-01 00:41:51,975 [INFO] [21/1400] PUBLISHED: Sales Executive / KAM | TeamQuest | Gdynia | https://solid.jobs/offer/25374/teamquest-sales-executive-kam
# 2025-12-01 00:41:53,889 [INFO] [22/1400] PUBLISHED: Sales Executive / KAM | TeamQuest | Warszawa | https://solid.jobs/offer/25375/teamquest-sales-executive-kam
# 2025-12-01 00:41:54,015 [INFO] [23/1400] PUBLISHED: Fullstack Developer (Java + Angular) | Scalo | Zdalnie | https://solid.jobs/offer/25388/scalo-fullstack-developer-java--angular
# 2025-12-01 00:41:56,591 [INFO] [24/1400] PUBLISHED: DevOps Engineer (AWS) | apreel | Warszawa | https://solid.jobs/offer/25389/speedapp-devops-engineer-aws
# 2025-12-01 00:42:00,864 [INFO] [25/1400] PUBLISHED: Administrator Systemów i Sieci | TeamQuest | Warszawa | https://solid.jobs/offer/25395/teamquest-administrator-systemow-i-sieci
# 2025-12-01 00:42:03,169 [INFO] [26/1400] PUBLISHED: Administrator of Systems and Networks | TeamQuest | Warszawa | https://solid.jobs/offer/25396/teamquest-administrator-of-systems-and-networks
# 2025-12-01 00:42:07,301 [INFO] [28/1400] PUBLISHED: MLOps Engineer | TeamQuest | Zdalnie | https://solid.jobs/offer/25404/teamquest-mlops-engineer
# 2025-12-01 00:42:07,398 [INFO] [27/1400] PUBLISHED: MLOps Engineer | TeamQuest | Zdalnie | https://solid.jobs/offer/25403/teamquest-mlops-engineer
# 2025-12-01 00:42:08,933 [INFO] [29/1400] PUBLISHED: Specjalista wsparcia IT - analiza techniczna sprzętu IT | TeamQuest | Warszawa | https://solid.jobs/offer/25405/teamquest-specjalista-wsparcia-it-analiza-techniczna-sprzetu-it
# 2025-12-01 00:42:12,285 [INFO] [30/1400] PUBLISHED: Mainframe (z/OS, Assembler) Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/25406/teamquest-mainframe-z-os-assembler-developer
# 2025-12-01 00:42:14,196 [INFO] [31/1400] PUBLISHED: Programista Mainframe (z/OS, Assembler) | TeamQuest | Zdalnie | https://solid.jobs/offer/25407/teamquest-programista-mainframe-z-os-assembler
# 2025-12-01 00:42:17,216 [INFO] [33/1400] PUBLISHED: Senior Administrator IT | TeamQuest | Warszawa | https://solid.jobs/offer/25409/teamquest-senior-administrator-it
# 2025-12-01 00:42:17,631 [INFO] [32/1400] PUBLISHED: Fullstack .NET Developer | TeamQuest | Warszawa | https://solid.jobs/offer/25408/teamquest-fullstack-dotnet-developer
# 2025-12-01 00:42:18,709 [INFO] [34/1400] PUBLISHED: Senior Administrator IT | TeamQuest | Warszawa | https://solid.jobs/offer/25410/teamquest-senior-administrator-it
# 2025-12-01 00:42:21,667 [INFO] [35/1400] PUBLISHED: Senior Software Developer (C++) | PowerMedia | Kraków / Zdalnie | https://solid.jobs/offer/25412/scalo-senior-software-developer-cplusplus
# 2025-12-01 00:42:24,435 [INFO] [36/1400] PUBLISHED: Senior Fullstack Engineer (React & Java / Kotlin) | apreel | Zdalnie | https://solid.jobs/offer/25418/scalo-senior-fullstack-engineer-react--java-kotlin
# 2025-12-01 00:42:27,817 [INFO] [37/1400] PUBLISHED: System Analyst (MS SQL + T-SQL) | Scalo | Wrocław | https://solid.jobs/offer/25443/scalo-system-analyst-ms-sql--tsql
# 2025-12-01 00:42:27,933 [INFO] [38/1400] PUBLISHED: Business Analyst | Scalo | Zdalnie | https://solid.jobs/offer/25444/scalo-business-analyst
# 2025-12-01 00:42:30,387 [INFO] [39/1400] PUBLISHED: Fullstack Developer (Java + React) | Scalo | Zdalnie | https://solid.jobs/offer/25447/scalo-fullstack-developer-java--react
# 2025-12-01 00:42:32,011 [INFO] [40/1400] PUBLISHED: Guidewire / Gosu Developer | apreel | Warszawa | https://solid.jobs/offer/25454/apreel-guidewire-gosu-developer
# 2025-12-01 00:42:36,369 [INFO] [41/1400] PUBLISHED: Big Data Lead / Manager | Godel Technologies Europe | Warszawa | https://solid.jobs/offer/25460/speedapp-big-data-lead-manager
# 2025-12-01 00:42:39,912 [INFO] [42/1400] PUBLISHED: Account Manager - Sprzedaż Usług Rekrutacyjnych | TeamQuest | Warszawa | https://solid.jobs/offer/25465/teamquest-account-manager-sprzedaz-uslug-rekrutacyjnych
# 2025-12-01 00:42:41,104 [INFO] [44/1400] PUBLISHED: Programista Kotlin | TeamQuest | Zdalnie | https://solid.jobs/offer/25469/teamquest-programista-kotlin
# 2025-12-01 00:42:41,669 [INFO] [43/1400] PUBLISHED: Kotlin Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/25468/teamquest-kotlin-developer
# 2025-12-01 00:42:42,985 [INFO] [45/1400] PUBLISHED: Key Account Manager (Usługi HR) | TeamQuest | Warszawa | https://solid.jobs/offer/25474/teamquest-key-account-manager-uslugi-hr
# 2025-12-01 00:42:45,546 [INFO] [46/1400] PUBLISHED: Junior Rekruter | TeamQuest | Warszawa | https://solid.jobs/offer/25475/teamquest-junior-rekruter
# 2025-12-01 00:42:49,270 [INFO] [47/1400] PUBLISHED: Młodszy Specjalista ds. wsparcia sprzedaży | TeamQuest | Warszawa | https://solid.jobs/offer/25476/teamquest-mlodszy-specjalista-ds-wsparcia-sprzedazy
# 2025-12-01 00:42:50,377 [INFO] [48/1400] PUBLISHED: Spedytor Międzynarodowy | TeamQuest | Zdalnie | https://solid.jobs/offer/25477/teamquest-spedytor-miedzynarodowy
# 2025-12-01 00:42:50,436 [INFO] [49/1400] PUBLISHED: Sales Assistant | TeamQuest | Warszawa | https://solid.jobs/offer/25478/teamquest-sales-assistant
# 2025-12-01 00:42:52,538 [INFO] [50/1400] PUBLISHED: Spedytor Międzynarodowy | TeamQuest | Zdalnie | https://solid.jobs/offer/25479/teamquest-spedytor-miedzynarodowy
# 2025-12-01 00:42:54,684 [INFO] [51/1400] PUBLISHED: IT Recruiter | TeamQuest | Warszawa | https://solid.jobs/offer/25480/teamquest-it-recruiter
# 2025-12-01 00:42:56,911 [INFO] [52/1400] PUBLISHED: Junior Rekruter | TeamQuest | Warszawa | https://solid.jobs/offer/25481/teamquest-junior-rekruter
# 2025-12-01 00:43:00,345 [INFO] [53/1400] PUBLISHED: International Freight Forwarder | TeamQuest | Zdalnie | https://solid.jobs/offer/25482/teamquest-international-freight-forwarder
# 2025-12-01 00:43:01,568 [INFO] [54/1400] PUBLISHED: Head of Social Media | TeamQuest | Trójmiasto | https://solid.jobs/offer/25483/teamquest-head-of-social-media
# 2025-12-01 00:43:03,356 [INFO] [55/1400] PUBLISHED: Senior Azure Engineer | apreel | Zdalnie | https://solid.jobs/offer/25493/apreel-senior-azure-engineer
# 2025-12-01 00:43:05,741 [INFO] [56/1400] PUBLISHED: Senior Python Developer z AWS | Godel Technologies Europe | Wrocław | https://solid.jobs/offer/25494/next-technology-professionals-senior-python-developer-z-aws
# 2025-12-01 00:43:09,382 [INFO] [57/1400] PUBLISHED: Senior Java Developer z AWS | Scalo | Zdalnie | https://solid.jobs/offer/25498/next-technology-professionals-senior-java-developer-z-aws
# 2025-12-01 00:43:10,673 [INFO] [59/1400] PUBLISHED: Senior Sharepoint Developer | 1dea | Zdalnie | https://solid.jobs/offer/25507/pp-solutions-senior-sharepoint-developer
# 2025-12-01 00:43:11,152 [INFO] [58/1400] PUBLISHED: AWS GCP Cyber Security Expert Consultant (Architect) | Next Technology Professionals | Zdalnie | https://solid.jobs/offer/25506/1dea-aws-gcp-cyber-security-expert-consultant-architect
# 2025-12-01 00:43:16,266 [INFO] [60/1400] PUBLISHED: PHP Developer | TeamQuest | Gdynia | https://solid.jobs/offer/25512/teamquest-php-developer
# 2025-12-01 00:43:20,310 [INFO] [61/1400] PUBLISHED: PHP Developer | TeamQuest | Gdynia | https://solid.jobs/offer/25513/teamquest-php-developer
# 2025-12-01 00:43:20,490 [INFO] [62/1400] PUBLISHED: PHP Developer | TeamQuest | Gdańsk | https://solid.jobs/offer/25514/teamquest-php-developer
# 2025-12-01 00:43:21,566 [INFO] [64/1400] PUBLISHED: Konsultant Wiodący SAP PP | TeamQuest | Zdalnie | https://solid.jobs/offer/25525/teamquest-konsultant-wiodacy-sap-pp
# 2025-12-01 00:43:21,673 [INFO] [63/1400] PUBLISHED: Programista Microsoft Dynamics 365 Finance & Operations (D365 F&O) | TeamQuest | Warszawa | https://solid.jobs/offer/25515/teamquest-programista-microsoft-dynamics-365-finance--operations-d365-fo
# 2025-12-01 00:43:24,380 [INFO] [65/1400] PUBLISHED: Leading SAP PP Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/25526/teamquest-leading-sap-pp-consultant
# 2025-12-01 00:43:31,689 [INFO] [66/1400] PUBLISHED: Fullstack .NET Developer | TeamQuest | Warszawa | https://solid.jobs/offer/25533/teamquest-fullstack-dotnet-developer
# 2025-12-01 00:43:32,015 [INFO] [67/1400] PUBLISHED: Senior Azure Engineer | apreel | Zdalnie | https://solid.jobs/offer/25535/apreel-senior-azure-engineer
# 2025-12-01 00:43:32,865 [INFO] [69/1400] PUBLISHED: PHP Fullstack Developer | TeamQuest | Kraków | https://solid.jobs/offer/25556/teamquest-php-fullstack-developer
# 2025-12-01 00:43:33,385 [INFO] [68/1400] PUBLISHED: Starszy Menadżer ds. Rozwoju Sprzedaży | 1dea | Warszawa | https://solid.jobs/offer/25548/pentacomp-systemy-informatyczne-starszy-menadzer-ds-rozwoju-sprzedazy
# 2025-12-01 00:43:35,013 [INFO] [70/1400] PUBLISHED: Scala Spark Engineer | Sqaure One | Zdalnie | https://solid.jobs/offer/25558/verita-hr-scala-spark-engineer
# 2025-12-01 00:43:39,724 [INFO] [71/1400] PUBLISHED: Rekruter IT | TeamQuest | Warszawa | https://solid.jobs/offer/25560/tqlo-rekruter-it
# 2025-12-01 00:43:42,155 [INFO] [72/1400] PUBLISHED: WEBCON Developer | speedapp | Zdalnie | https://solid.jobs/offer/25572/teamquest-webcon-developer
# 2025-12-01 00:43:43,038 [INFO] [73/1400] PUBLISHED: PHP Developer (Fullstack) | TeamQuest | Kraków | https://solid.jobs/offer/25573/teamquest-php-developer-fullstack
# 2025-12-01 00:43:45,078 [INFO] [74/1400] PUBLISHED: System Administrator | TeamQuest | Warszawa | https://solid.jobs/offer/25592/sqaure-one-system-administrator
# 2025-12-01 00:43:48,837 [INFO] [75/1400] PUBLISHED: Administrator IT | TeamQuest | Warszawa | https://solid.jobs/offer/25593/teamquest-administrator-it
# 2025-12-01 00:43:51,370 [INFO] [76/1400] PUBLISHED: IT Administrator | TeamQuest | Warszawa | https://solid.jobs/offer/25594/teamquest-it-administrator
# 2025-12-01 00:43:52,883 [INFO] [77/1400] PUBLISHED: Specjalista rekrutacji IT | TeamQuest | Warszawa | https://solid.jobs/offer/25605/teamquest-specjalista-rekrutacji-it
# 2025-12-01 00:43:55,895 [INFO] [78/1400] PUBLISHED: Senior IT Recruitment Consultant | TeamQuest | Warszawa | https://solid.jobs/offer/25606/teamquest-senior-it-recruitment-consultant
# 2025-12-01 00:43:55,966 [INFO] [79/1400] PUBLISHED: PC Hardware Expert / Specjalista PC | TeamQuest | Warszawa | https://solid.jobs/offer/25607/teamquest-pc-hardware-expert-specjalista-pc
# 2025-12-01 00:43:58,520 [INFO] [80/1400] PUBLISHED: Specjalista ds. Sprzętu Komputerowego | TeamQuest | Warszawa | https://solid.jobs/offer/25608/teamquest-specjalista-ds-sprzetu-komputerowego
# 2025-12-01 00:44:02,617 [INFO] [81/1400] PUBLISHED: Software Solution Architect | apreel | Warszawa | https://solid.jobs/offer/25618/apreel-software-solution-architect
# 2025-12-01 00:44:04,461 [INFO] [82/1400] PUBLISHED: Fullstack .NET Engineer | Godel Technologies Europe | Łódź | https://solid.jobs/offer/25624/godel-technologies-europe-fullstack-dotnet-engineer
# 2025-12-01 00:44:06,954 [INFO] [84/1400] PUBLISHED: Fullstack .NET Engineer | Scalo | Gdynia | https://solid.jobs/offer/25627/godel-technologies-europe-fullstack-dotnet-engineer
# 2025-12-01 00:44:07,073 [INFO] [83/1400] PUBLISHED: Fullstack .NET Engineer | P&P Solutions | Wrocław | https://solid.jobs/offer/25626/godel-technologies-europe-fullstack-dotnet-engineer
# 2025-12-01 00:44:08,097 [INFO] [85/1400] PUBLISHED: Senior Key Account Manager IT | TeamQuest | Zdalnie | https://solid.jobs/offer/25635/teamquest-senior-key-account-manager-it
# 2025-12-01 00:44:12,980 [INFO] [86/1400] PUBLISHED: IT Hardware Specialist - Wsparcie i Konfiguracja | TeamQuest | Warszawa | https://solid.jobs/offer/25636/teamquest-it-hardware-specialist-wsparcie-i-konfiguracja
# 2025-12-01 00:44:15,552 [INFO] [87/1400] PUBLISHED: Starszy Konsultant SAP - obszar PP | TeamQuest | Zdalnie | https://solid.jobs/offer/25639/teamquest-starszy-konsultant-sap-obszar-pp
# 2025-12-01 00:44:16,946 [INFO] [88/1400] PUBLISHED: Sales Director (Cloud solutions) | TeamQuest | Warszawa | https://solid.jobs/offer/25640/teamquest-sales-director-cloud-solutions
# 2025-12-01 00:44:17,680 [INFO] [89/1400] PUBLISHED: Dyrektor Sprzedaży (rozwiązania Cloud) | TeamQuest | Warszawa | https://solid.jobs/offer/25641/teamquest-dyrektor-sprzedazy-rozwiazania-cloud
# 2025-12-01 00:44:20,998 [INFO] [90/1400] PUBLISHED: Team Lead Data Engineer (obszar Snowflake) | TeamQuest | Zdalnie | https://solid.jobs/offer/25642/teamquest-team-lead-data-engineer-obszar-snowflake
# 2025-12-01 00:44:25,164 [INFO] [91/1400] PUBLISHED: Team Lead Data Engineer (Snowflake) | TeamQuest | Zdalnie | https://solid.jobs/offer/25643/teamquest-team-lead-data-engineer-snowflake
# 2025-12-01 00:44:27,052 [INFO] [92/1400] PUBLISHED: Senior Fullstack Engineer | Verita HR | Kraków | https://solid.jobs/offer/25645/verita-hr-senior-fullstack-engineer
# 2025-12-01 00:44:28,718 [INFO] [93/1400] PUBLISHED: Data Engineer | Verita HR | Kraków | https://solid.jobs/offer/25646/verita-hr-data-engineer
# 2025-12-01 00:44:30,838 [INFO] [94/1400] PUBLISHED: IT Business Analyst | Verita HR | Kraków | https://solid.jobs/offer/25647/verita-hr-it-business-analyst
# 2025-12-01 00:44:33,162 [INFO] [95/1400] PUBLISHED: Business Systems Analyst | apreel | Warszawa / Zdalnie | https://solid.jobs/offer/25655/sqaure-one-business-systems-analyst
# 2025-12-01 00:44:36,638 [INFO] [96/1400] PUBLISHED: Fullstack Developer (.NET + React) | apreel | Warszawa | https://solid.jobs/offer/25671/apreel-fullstack-developer-dotnet--react
# 2025-12-01 00:44:39,819 [INFO] [97/1400] PUBLISHED: Website Operations Manager | P&P Solutions | Zdalnie | https://solid.jobs/offer/25694/pp-solutions-website-operations-manager
# 2025-12-01 00:44:41,425 [INFO] [98/1400] PUBLISHED: Backend Developer (Node.js + GCP) | 1dea | Zdalnie | https://solid.jobs/offer/25699/1dea-backend-developer-nodejs--gcp
# 2025-12-01 00:44:42,742 [INFO] [99/1400] PUBLISHED: Mid/Senior IT Recruiter | TeamQuest | Warszawa | https://solid.jobs/offer/25700/teamquest-mid-senior-it-recruiter
# 2025-12-01 00:44:44,265 [INFO] [100/1400] PUBLISHED: Starszy Analityk Systemowy | speedapp | Warszawa | https://solid.jobs/offer/25706/lumicode-grupa-pentacomp-starszy-analityk-systemowy
# 2025-12-01 00:44:47,668 [INFO] [101/1400] PUBLISHED: Data Engineer | Infolet | Zdalnie | https://solid.jobs/offer/25708/apreel-data-engineer
# 2025-12-01 00:44:48,756 [INFO] [102/1400] PUBLISHED: Konsultant SAP HCM | TeamQuest | Zdalnie | https://solid.jobs/offer/25717/teamquest-konsultant-sap-hcm
# 2025-12-01 00:44:49,786 [INFO] [103/1400] PUBLISHED: SAP HCR Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/25718/teamquest-sap-hcr-consultant
# 2025-12-01 00:44:53,165 [INFO] [104/1400] PUBLISHED: Konsultant SAP HCM | TeamQuest | Zdalnie | https://solid.jobs/offer/25719/teamquest-konsultant-sap-hcm
# 2025-12-01 00:44:56,148 [INFO] [105/1400] PUBLISHED: Senior C Developer | 1dea | Kraków | https://solid.jobs/offer/25726/power-media-senior-c-developer
# 2025-12-01 00:44:56,763 [INFO] [106/1400] PUBLISHED: Account Manager | TeamQuest | Łódź | https://solid.jobs/offer/25729/teamquest-account-manager
# 2025-12-01 00:44:57,930 [INFO] [107/1400] PUBLISHED: SAP ABAP Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/25730/teamquest-sap-abap-developer
# 2025-12-01 00:44:59,653 [INFO] [108/1400] PUBLISHED: Strategic Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/25731/teamquest-strategic-account-manager
# 2025-12-01 00:45:00,134 [INFO] [109/1400] PUBLISHED: Senior Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/25732/teamquest-senior-account-manager
# 2025-12-01 00:45:07,264 [INFO] [110/1400] PUBLISHED: Senior Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/25733/teamquest-senior-account-manager
# 2025-12-01 00:45:09,373 [INFO] [111/1400] PUBLISHED: Senior Fullstack Developer | TeamQuest | Warszawa | https://solid.jobs/offer/25741/teamquest-senior-fullstack-developer
# 2025-12-01 00:45:09,824 [INFO] [112/1400] PUBLISHED: Presales Engineer IT | TeamQuest | Warszawa | https://solid.jobs/offer/25742/teamquest-presales-engineer-it
# 2025-12-01 00:45:09,902 [INFO] [113/1400] PUBLISHED: Key Account Manager IT | TeamQuest | Warszawa | https://solid.jobs/offer/25743/teamquest-key-account-manager-it
# 2025-12-01 00:45:14,415 [INFO] [114/1400] PUBLISHED: Senior C++ Developer | speedapp | Warszawa | https://solid.jobs/offer/25754/teamquest-senior-cplusplus-developer
# 2025-12-01 00:45:16,893 [INFO] [115/1400] PUBLISHED: Senior Android Developer (Java) | TeamQuest | Wrocław | https://solid.jobs/offer/25772/teamquest-senior-android-developer-java
# 2025-12-01 00:45:21,108 [INFO] [116/1400] PUBLISHED: Customer Service with Spanish + translation | TeamQuest | Warszawa | https://solid.jobs/offer/25786/teamquest-customer-service-with-spanish--translation
# 2025-12-01 00:45:22,353 [INFO] [118/1400] PUBLISHED: Administrator Sieci | P&P Solutions | Zdalnie | https://solid.jobs/offer/25794/apreel-administrator-sieci
# 2025-12-01 00:45:22,997 [INFO] [117/1400] PUBLISHED: Administrator Sieci | apreel | Warszawa | https://solid.jobs/offer/25792/lumicode-grupa-pentacomp-administrator-sieci
# 2025-12-01 00:45:27,871 [INFO] [120/1400] PUBLISHED: Specjalista/tka ds. Administracji | TeamQuest | Warszawa | https://solid.jobs/offer/25813/teamquest-specjalista-tka-ds-administracji
# 2025-12-01 00:45:28,385 [INFO] [119/1400] PUBLISHED: Spryker Developer | Dev4Hire | Zdalnie | https://solid.jobs/offer/25798/dev4hire-spryker-developer
# 2025-12-01 00:45:30,304 [INFO] [121/1400] PUBLISHED: Specialist in Administration | TeamQuest | Warszawa | https://solid.jobs/offer/25814/teamquest-specialist-in-administration
# 2025-12-01 00:45:33,814 [INFO] [122/1400] PUBLISHED: Azure DevOps Cloud Engineer | Verita HR | Kraków | https://solid.jobs/offer/25824/hro-digital-verita-hr-azure-devops-cloud-engineer
# 2025-12-01 00:45:34,627 [INFO] [123/1400] PUBLISHED: Expert MLOps Engineer | apreel | Zdalnie | https://solid.jobs/offer/25825/apreel-expert-mlops-engineer
# 2025-12-01 00:45:39,083 [INFO] [125/1400] PUBLISHED: MLOps Engineer | apreel | Zdalnie | https://solid.jobs/offer/25830/apreel-mlops-engineer
# 2025-12-01 00:45:40,292 [INFO] [124/1400] PUBLISHED: Data Engineer AWS | System Verification Poland | Zdalnie | https://solid.jobs/offer/25826/apreel-data-engineer-aws
# 2025-12-01 00:45:40,451 [INFO] [126/1400] PUBLISHED: Strategic Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/25831/teamquest-strategic-account-manager
# 2025-12-01 00:45:42,609 [INFO] [127/1400] PUBLISHED: Specjalista ds. Organizacji | TeamQuest | Warszawa | https://solid.jobs/offer/25840/teamquest-specjalista-ds-organizacji
# 2025-12-01 00:45:43,375 [INFO] [128/1400] PUBLISHED: Key Account Manager IT | TeamQuest | Zdalnie | https://solid.jobs/offer/25843/teamquest-key-account-manager-it
# 2025-12-01 00:45:46,445 [INFO] [129/1400] PUBLISHED: Asystent ds. Administracji | TeamQuest | Warszawa | https://solid.jobs/offer/25844/teamquest-asystent-ds-administracji
# 2025-12-01 00:45:50,656 [INFO] [131/1400] PUBLISHED: Product Owner | Verita HR | Kraków | https://solid.jobs/offer/25859/verita-hr-product-owner
# 2025-12-01 00:45:51,604 [INFO] [130/1400] PUBLISHED: Senior Java Backend Engineer | Verita HR | Kraków | https://solid.jobs/offer/25850/verita-hr-senior-java-backend-engineer
# 2025-12-01 00:45:52,777 [INFO] [132/1400] PUBLISHED: Product Owner / SaaS Growth Strategist | BrainForge IT Software & Consulting | Zdalnie | https://solid.jobs/offer/25864/power-media-product-owner-saas-growth-strategist
# 2025-12-01 00:45:53,327 [INFO] [133/1400] PUBLISHED: Konsultant wdrożeniowy (systemy controlingowe) | TeamQuest | Zdalnie | https://solid.jobs/offer/25872/teamquest-konsultant-wdrozeniowy-systemy-controlingowe
# 2025-12-01 00:45:56,320 [INFO] [134/1400] PUBLISHED: Controlling systems Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/25873/teamquest-controlling-systems-consultant
# 2025-12-01 00:46:02,183 [INFO] [135/1400] PUBLISHED: Specjalista ds. Sprzętu Komputerowego | TeamQuest | Warszawa | https://solid.jobs/offer/25874/teamquest-specjalista-ds-sprzetu-komputerowego
# 2025-12-01 00:46:02,951 [INFO] [136/1400] PUBLISHED: Developer .NET | TeamQuest | Piaseczno | https://solid.jobs/offer/25875/teamquest-developer-dotnet
# 2025-12-01 00:46:04,419 [INFO] [137/1400] PUBLISHED: Asystent ds. Sprzedaży i Rozwoju Klienta | TeamQuest | Warszawa | https://solid.jobs/offer/25876/teamquest-asystent-ds-sprzedazy-i-rozwoju-klienta
# 2025-12-01 00:46:06,188 [INFO] [138/1400] PUBLISHED: Product Owner | Verita HR | Kraków | https://solid.jobs/offer/25888/verita-hr-product-owner
# 2025-12-01 00:46:12,143 [INFO] [139/1400] PUBLISHED: Product Owner | Decentra Planet | Warszawa / Zdalnie | https://solid.jobs/offer/25900/verita-hr-product-owner
# 2025-12-01 00:46:13,208 [INFO] [141/1400] PUBLISHED: .NET Developer | Click IT Group | Zdalnie | https://solid.jobs/offer/25902/scalo-dotnet-developer
# 2025-12-01 00:46:13,819 [INFO] [140/1400] PUBLISHED: PHP Developer | TeamQuest | Gdańsk | https://solid.jobs/offer/25901/teamquest-php-developer
# 2025-12-01 00:46:15,931 [INFO] [142/1400] PUBLISHED: ETL Tester | 1dea | Zdalnie | https://solid.jobs/offer/25903/arche-consulting-etl-tester
# 2025-12-01 00:46:17,756 [INFO] [143/1400] PUBLISHED: Mid/Senior iOS Developer + Kotlin Multiplatform | apreel | Zdalnie | https://solid.jobs/offer/25910/apreel-mid-senior-ios-developer--kotlin-multiplatform
# 2025-12-01 00:46:22,166 [INFO] [144/1400] PUBLISHED: BI Developer | TeamQuest | Warszawa | https://solid.jobs/offer/25916/teamquest-bi-developer
# 2025-12-01 00:46:23,778 [INFO] [146/1400] PUBLISHED: Fullstack Developer (.NET + React) | Godel Technologies Europe | Gdańsk | https://solid.jobs/offer/25930/scalo-fullstack-developer-dotnet--react
# 2025-12-01 00:46:23,913 [INFO] [145/1400] PUBLISHED: DevOps Engineer | TeamQuest | Warszawa | https://solid.jobs/offer/25928/teamquest-devops-engineer
# 2025-12-01 00:46:28,319 [INFO] [147/1400] PUBLISHED: Senior Cloud DevOps Engineer / Admin | TeamQuest | Warszawa | https://solid.jobs/offer/25931/scalo-senior-cloud-devops-engineer-admin
# 2025-12-01 00:46:29,720 [INFO] [148/1400] PUBLISHED: Senior Fullstack Developer (Java + Angular) | Scalo | Zdalnie | https://solid.jobs/offer/25932/scalo-senior-fullstack-developer-java--angular
# 2025-12-01 00:46:33,508 [INFO] [149/1400] PUBLISHED: Senior System Analyst | Scalo | Zdalnie | https://solid.jobs/offer/25933/scalo-senior-system-analyst
# 2025-12-01 00:46:38,321 [INFO] [150/1400] PUBLISHED: Fullstack Developer (Java + Angular) | Scalo | Warszawa | https://solid.jobs/offer/25934/scalo-fullstack-developer-java--angular
# 2025-12-01 00:46:38,840 [INFO] [151/1400] PUBLISHED: Scala Developer (Spark) | Scalo | Warszawa | https://solid.jobs/offer/25935/scalo-scala-developer-spark
# 2025-12-01 00:46:40,011 [INFO] [153/1400] PUBLISHED: Administrator Systemów Biznesowych | Scalo | Warszawa | https://solid.jobs/offer/25952/pp-solutions-administrator-systemow-biznesowych
# 2025-12-01 00:46:42,573 [INFO] [152/1400] PUBLISHED: Fullstack Developer (.NET + Angular) | 1dea | Warszawa | https://solid.jobs/offer/25938/scalo-fullstack-developer-dotnet--angular
# 2025-12-01 00:46:42,777 [INFO] [154/1400] PUBLISHED: Senior Key Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/25959/teamquest-senior-key-account-manager
# 2025-12-01 00:46:48,129 [INFO] [156/1400] PUBLISHED: IT Hardware and Technical Support Specialist | TeamQuest | Warszawa | https://solid.jobs/offer/25969/teamquest-it-hardware-and-technical-support-specialist
# 2025-12-01 00:46:48,965 [INFO] [155/1400] PUBLISHED: System - Business Analyst | Scalo | Wrocław | https://solid.jobs/offer/25960/scalo-system-business-analyst
# 2025-12-01 00:46:49,840 [INFO] [157/1400] PUBLISHED: Technik IT - Konfiguracja i Wsparcie Sprzętowe | TeamQuest | Warszawa | https://solid.jobs/offer/25970/teamquest-technik-it-konfiguracja-i-wsparcie-sprzetowe
# 2025-12-01 00:46:53,278 [INFO] [159/1400] PUBLISHED: Analityk Biznesowo - Systemowy (AML) | Scalo | Zdalnie | https://solid.jobs/offer/25972/scalo-analityk-biznesowo-systemowy-aml
# 2025-12-01 00:46:53,492 [INFO] [158/1400] PUBLISHED: Technique IT - Hardware Configuration and Support | TeamQuest | Warszawa | https://solid.jobs/offer/25971/teamquest-technique-it-hardware-configuration-and-support
# 2025-12-01 00:46:58,407 [INFO] [160/1400] PUBLISHED: Senior Oracle Developer | Arche Consulting | Zdalnie | https://solid.jobs/offer/25974/pp-solutions-senior-oracle-developer
# 2025-12-01 00:46:59,766 [INFO] [161/1400] PUBLISHED: Power Platform Developer | apreel | Zdalnie | https://solid.jobs/offer/25976/apreel-power-platform-developer
# 2025-12-01 00:47:02,315 [INFO] [163/1400] PUBLISHED: Programista Oracle | P&P Solutions | Wrocław / Zdalnie | https://solid.jobs/offer/25980/arche-consulting-programista-oracle
# 2025-12-01 00:47:03,106 [INFO] [162/1400] PUBLISHED: Specjalista ds. Sprzętu IT i Wsparcia Technicznego | TeamQuest | Warszawa | https://solid.jobs/offer/25979/teamquest-specjalista-ds-sprzetu-it-i-wsparcia-technicznego
# 2025-12-01 00:47:04,118 [INFO] [164/1400] PUBLISHED: DevOps Engineer | apreel | Warszawa | https://solid.jobs/offer/25983/apreel-devops-engineer
# 2025-12-01 00:47:10,040 [INFO] [165/1400] PUBLISHED: Backend Java Developer (Payments Services) | Verita HR | Kraków | https://solid.jobs/offer/25985/verita-hr-backend-java-developer-payments-services
# 2025-12-01 00:47:11,116 [INFO] [166/1400] PUBLISHED: Przedstawiciel handlowy / KAM (branża TSL) | TeamQuest | Gdynia | https://solid.jobs/offer/25986/teamquest-przedstawiciel-handlowy-kam-branza-tsl
# 2025-12-01 00:47:12,851 [INFO] [167/1400] PUBLISHED: Przedstawiciel handlowy / KAM (branża TSL) | TeamQuest | Warszawa | https://solid.jobs/offer/25987/teamquest-przedstawiciel-handlowy-kam-branza-tsl
# 2025-12-01 00:47:13,351 [INFO] [168/1400] PUBLISHED: Business - System Analyst | Scalo | Wrocław | https://solid.jobs/offer/25994/scalo-business-system-analyst
# 2025-12-01 00:47:15,805 [INFO] [169/1400] PUBLISHED: Senior Automation Tester / QA (C#) | Scalo | Zdalnie | https://solid.jobs/offer/25995/scalo-senior-automation-tester-qa-csharp
# 2025-12-01 00:47:19,790 [INFO] [170/1400] PUBLISHED: Informatica Power Center Developer | Godel Technologies Europe | Łódź | https://solid.jobs/offer/25998/scalo-informatica-power-center-developer
# 2025-12-01 00:47:21,673 [INFO] [171/1400] PUBLISHED: ETL Developer (Enterprise Data Migrator) | Arche Consulting | Zdalnie | https://solid.jobs/offer/26007/arche-consulting-etl-developer-enterprise-data-migrator
# 2025-12-01 00:47:21,864 [INFO] [172/1400] PUBLISHED: Programista Mainframe (z/OS, Assembler) | TeamQuest | Zdalnie | https://solid.jobs/offer/26012/teamquest-programista-mainframe-z-os-assembler
# 2025-12-01 00:47:22,302 [INFO] [173/1400] PUBLISHED: Mainframe (z/OS, Assembler) Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/26013/teamquest-mainframe-z-os-assembler-developer
# 2025-12-01 00:47:24,815 [INFO] [174/1400] PUBLISHED: Specjalista wsparcia IT - analiza techniczna sprzętu IT | TeamQuest | Warszawa | https://solid.jobs/offer/26014/teamquest-specjalista-wsparcia-it-analiza-techniczna-sprzetu-it
# 2025-12-01 00:47:27,719 [INFO] [175/1400] PUBLISHED: Programista Kotlin | TeamQuest | Zdalnie | https://solid.jobs/offer/26015/teamquest-programista-kotlin
# 2025-12-01 00:47:29,786 [INFO] [176/1400] PUBLISHED: Kotlin Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/26016/teamquest-kotlin-developer
# 2025-12-01 00:47:31,154 [INFO] [178/1400] PUBLISHED: Account Manager - Sprzedaż Usług Rekrutacyjnych | TeamQuest | Warszawa | https://solid.jobs/offer/26019/teamquest-account-manager-sprzedaz-uslug-rekrutacyjnych
# 2025-12-01 00:47:31,384 [INFO] [177/1400] PUBLISHED: Senior Frontend Developer (React + React Native) | TeamQuest | Zdalnie | https://solid.jobs/offer/26017/teamquest-senior-frontend-developer-react--react-native
# 2025-12-01 00:47:36,746 [INFO] [180/1400] PUBLISHED: Junior Rekruter | TeamQuest | Warszawa | https://solid.jobs/offer/26023/teamquest-junior-rekruter
# 2025-12-01 00:47:36,820 [INFO] [179/1400] PUBLISHED: Key Account Manager (Usługi HR) | TeamQuest | Warszawa | https://solid.jobs/offer/26020/teamquest-key-account-manager-uslugi-hr
# 2025-12-01 00:47:41,499 [INFO] [181/1400] PUBLISHED: Kotlin Developer | apreel | Zdalnie | https://solid.jobs/offer/26028/apreel-kotlin-developer
# 2025-12-01 00:47:43,003 [INFO] [183/1400] PUBLISHED: Analityk Biznesowy | apreel | Warszawa | https://solid.jobs/offer/26032/power-media-analityk-biznesowy
# 2025-12-01 00:47:44,678 [INFO] [182/1400] PUBLISHED: Kotlin Backend Developer | apreel | Zdalnie | https://solid.jobs/offer/26029/apreel-kotlin-backend-developer
# 2025-12-01 00:47:47,919 [INFO] [185/1400] PUBLISHED: IT Recruiter | TeamQuest | Warszawa | https://solid.jobs/offer/26037/teamquest-it-recruiter
# 2025-12-01 00:47:48,273 [INFO] [184/1400] PUBLISHED: Młodszy Specjalista ds. wsparcia sprzedaży | TeamQuest | Warszawa | https://solid.jobs/offer/26034/teamquest-mlodszy-specjalista-ds-wsparcia-sprzedazy
# 2025-12-01 00:47:51,342 [INFO] [186/1400] PUBLISHED: Spedytor Międzynarodowy | TeamQuest | Zdalnie | https://solid.jobs/offer/26038/teamquest-spedytor-miedzynarodowy
# 2025-12-01 00:47:55,012 [INFO] [187/1400] PUBLISHED: Sales Assistant | TeamQuest | Warszawa | https://solid.jobs/offer/26039/teamquest-sales-assistant
# 2025-12-01 00:47:55,338 [INFO] [188/1400] PUBLISHED: Application Security Engineer | PTT Consulting | Zdalnie | https://solid.jobs/offer/26041/ptt-consulting-application-security-engineer
# 2025-12-01 00:47:56,156 [INFO] [189/1400] PUBLISHED: Tech Lead Application Security | PTT Consulting | Warszawa / Zdalnie | https://solid.jobs/offer/26043/ptt-consulting-tech-lead-application-security
# 2025-12-01 00:47:57,103 [INFO] [190/1400] PUBLISHED: Application Security Engineer | PTT Consulting | Zdalnie | https://solid.jobs/offer/26044/ptt-consulting-application-security-engineer
# 2025-12-01 00:48:03,513 [INFO] [191/1400] PUBLISHED: DevOps Engineer | apreel | Warszawa | https://solid.jobs/offer/26045/apreel-devops-engineer
# 2025-12-01 00:48:05,617 [INFO] [192/1400] PUBLISHED: Automation Developer | apreel | Zdalnie | https://solid.jobs/offer/26047/apreel-automation-developer
# 2025-12-01 00:48:11,267 [INFO] [195/1400] PUBLISHED: DevOps / Inżynier chmurowy | Next Technology Professionals | Zdalnie | https://solid.jobs/offer/26057/apreel-devops-inzynier-chmurowy
# 2025-12-01 00:48:11,589 [INFO] [193/1400] PUBLISHED: Administrator Sieci (GCP) | Lumicode (Grupa Pentacomp) | Warszawa | https://solid.jobs/offer/26055/apreel-administrator-sieci-gcp
# 2025-12-01 00:48:12,681 [INFO] [194/1400] PUBLISHED: Inżynier Chmurowy | apreel | Warszawa | https://solid.jobs/offer/26056/apreel-inzynier-chmurowy
# 2025-12-01 00:48:15,227 [INFO] [196/1400] PUBLISHED: Analityk Systemowy | Lumicode (Grupa Pentacomp) | Zdalnie | https://solid.jobs/offer/26059/speedapp-analityk-systemowy
# 2025-12-01 00:48:18,271 [INFO] [197/1400] PUBLISHED: Senior iOS Developer | HRO Digital/Verita HR | Kraków | https://solid.jobs/offer/26064/verita-hr-senior-ios-developer
# 2025-12-01 00:48:23,145 [INFO] [198/1400] PUBLISHED: Java Fullstack Developer | ITP IT Performance | Kraków | https://solid.jobs/offer/26065/verita-hr-java-fullstack-developer
# 2025-12-01 00:48:26,601 [INFO] [199/1400] PUBLISHED: Mobile Test Automation Engineer | Verita HR | Kraków | https://solid.jobs/offer/26066/verita-hr-mobile-test-automation-engineer
# 2025-12-01 00:48:27,040 [INFO] [200/1400] PUBLISHED: iOS Developer | Verita HR | Kraków | https://solid.jobs/offer/26067/hro-digital-verita-hr-ios-developer
# 2025-12-01 00:48:28,883 [INFO] [201/1400] PUBLISHED: Android Developer | Verita HR | Kraków | https://solid.jobs/offer/26068/verita-hr-android-developer
# 2025-12-01 00:48:32,224 [INFO] [202/1400] PUBLISHED: Senior DevOps Engineer | apreel | Warszawa | https://solid.jobs/offer/26069/apreel-senior-devops-engineer
# 2025-12-01 00:48:33,660 [INFO] [203/1400] PUBLISHED: Senior IT Cost and Contract Manager | ITFS | Zdalnie | https://solid.jobs/offer/26074/verita-hr-senior-it-cost-and-contract-manager
# 2025-12-01 00:48:38,104 [INFO] [205/1400] PUBLISHED: Junior Rekruter | TeamQuest | Warszawa | https://solid.jobs/offer/26086/teamquest-junior-rekruter
# 2025-12-01 00:48:38,932 [INFO] [204/1400] PUBLISHED: Fullstack Engineer (Java) | Verita HR | Kraków | https://solid.jobs/offer/26078/verita-hr-fullstack-engineer-java
# 2025-12-01 00:48:42,502 [INFO] [206/1400] PUBLISHED: Senior Java Engineer | Verita HR | Kraków | https://solid.jobs/offer/26091/verita-hr-senior-java-engineer
# 2025-12-01 00:48:46,476 [INFO] [207/1400] PUBLISHED: GCP DevOps Engineer | Verita HR | Kraków | https://solid.jobs/offer/26093/verita-hr-gcp-devops-engineer
# 2025-12-01 00:48:47,632 [INFO] [208/1400] PUBLISHED: Head of Social Media | TeamQuest | Trójmiasto | https://solid.jobs/offer/26098/teamquest-head-of-social-media
# 2025-12-01 00:48:51,276 [INFO] [209/1400] PUBLISHED: Senior DevOps Engineer (AWS) | TeamQuest | Warszawa | https://solid.jobs/offer/26099/teamquest-senior-devops-engineer-aws
# 2025-12-01 00:48:52,171 [INFO] [210/1400] PUBLISHED: Administrator Sieci | apreel | Warszawa | https://solid.jobs/offer/26109/lumicode-grupa-pentacomp-administrator-sieci
# 2025-12-01 00:48:54,763 [INFO] [211/1400] PUBLISHED: Koordynator ds. Bezpieczeństwa IT | apreel | Warszawa | https://solid.jobs/offer/26112/speedapp-koordynator-ds-bezpieczenstwa-it
# 2025-12-01 00:48:55,954 [INFO] [212/1400] PUBLISHED: Konsultant SAP FSCM (Fiori) | 1dea | Zdalnie | https://solid.jobs/offer/26118/1dea-konsultant-sap-fscm-fiori
# 2025-12-01 00:48:58,563 [INFO] [213/1400] PUBLISHED: Web Publisher | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26123/leasingteam-professional-web-publisher
# 2025-12-01 00:49:00,768 [INFO] [214/1400] PUBLISHED: Database Administrator | apreel | Zdalnie | https://solid.jobs/offer/26125/apreel-database-administrator
# 2025-12-01 00:49:02,118 [INFO] [215/1400] PUBLISHED: Administrator Stron Internetowych | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26130/leasingteam-professional-administrator-stron-internetowych
# 2025-12-01 00:49:05,057 [INFO] [216/1400] PUBLISHED: Senior Android Developer | apreel | Warszawa | https://solid.jobs/offer/26134/verita-hr-senior-android-developer
# 2025-12-01 00:49:08,425 [INFO] [217/1400] PUBLISHED: Programista Microsoft Dynamics 365 Finance & Operations (D365 F&O) | TeamQuest | Warszawa | https://solid.jobs/offer/26135/teamquest-programista-microsoft-dynamics-365-finance--operations-d365-fo
# 2025-12-01 00:49:11,941 [INFO] [218/1400] PUBLISHED: PHP Developer | TeamQuest | Gdynia | https://solid.jobs/offer/26136/teamquest-php-developer
# 2025-12-01 00:49:13,643 [INFO] [220/1400] PUBLISHED: PHP Developer | TeamQuest | Gdynia | https://solid.jobs/offer/26138/teamquest-php-developer
# 2025-12-01 00:49:14,480 [INFO] [221/1400] PUBLISHED: Android Developer (Java) | TeamQuest | Wrocław | https://solid.jobs/offer/26139/teamquest-android-developer-java
# 2025-12-01 00:49:14,656 [INFO] [219/1400] PUBLISHED: PHP Developer | TeamQuest | Gdynia | https://solid.jobs/offer/26137/teamquest-php-developer
# 2025-12-01 00:49:17,575 [INFO] [222/1400] PUBLISHED: Database Administrator | apreel | Zdalnie | https://solid.jobs/offer/26140/apreel-database-administrator
# 2025-12-01 00:49:22,404 [INFO] [223/1400] PUBLISHED: Mobile Test Automation Engineer | Verita HR | Kraków | https://solid.jobs/offer/26143/verita-hr-mobile-test-automation-engineer
# 2025-12-01 00:49:26,240 [INFO] [226/1400] PUBLISHED: Konsultant Wiodący SAP PP | TeamQuest | Zdalnie | https://solid.jobs/offer/26156/teamquest-konsultant-wiodacy-sap-pp
# 2025-12-01 00:49:27,029 [INFO] [224/1400] PUBLISHED: Fullstack Java Developer | apreel | Warszawa | https://solid.jobs/offer/26148/apreel-fullstack-java-developer
# 2025-12-01 00:49:27,673 [INFO] [225/1400] PUBLISHED: Content Publisher | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26154/leasingteam-professional-content-publisher
# 2025-12-01 00:49:31,450 [INFO] [227/1400] PUBLISHED: Senior Data Engineer | 1dea | Zdalnie | https://solid.jobs/offer/26159/apreel-senior-data-engineer
# 2025-12-01 00:49:33,819 [INFO] [228/1400] PUBLISHED: Senior Data Solution Architect | apreel | Zdalnie | https://solid.jobs/offer/26161/verita-hr-senior-data-solution-architect
# 2025-12-01 00:49:36,697 [INFO] [229/1400] PUBLISHED: Leading SAP PP Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/26163/teamquest-leading-sap-pp-consultant
# 2025-12-01 00:49:38,007 [INFO] [230/1400] PUBLISHED: PHP Fullstack Developer | TeamQuest | Kraków | https://solid.jobs/offer/26170/teamquest-php-fullstack-developer
# 2025-12-01 00:49:38,809 [INFO] [231/1400] PUBLISHED: Junior Website Administrator | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26172/leasingteam-professional-junior-website-administrator
# 2025-12-01 00:49:40,529 [INFO] [232/1400] PUBLISHED: Junior Website Administrator | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26173/leasingteam-professional-junior-website-administrator
# 2025-12-01 00:49:45,988 [INFO] [233/1400] PUBLISHED: Lead Python Developer (GenAI) | System Verification Poland | Zdalnie | https://solid.jobs/offer/26177/1dea-lead-python-developer-genai
# 2025-12-01 00:49:46,204 [INFO] [234/1400] PUBLISHED: PHP Developer (Fullstack) | TeamQuest | Kraków | https://solid.jobs/offer/26178/teamquest-php-developer-fullstack
# 2025-12-01 00:49:47,273 [INFO] [235/1400] PUBLISHED: IT Administrator | TeamQuest | Warszawa | https://solid.jobs/offer/26179/teamquest-it-administrator
# 2025-12-01 00:49:49,741 [INFO] [236/1400] PUBLISHED: Administrator IT | TeamQuest | Warszawa | https://solid.jobs/offer/26180/teamquest-administrator-it
# 2025-12-01 00:49:50,442 [INFO] [237/1400] PUBLISHED: Specjalista ds. Sprzętu Komputerowego | TeamQuest | Warszawa | https://solid.jobs/offer/26181/teamquest-specjalista-ds-sprzetu-komputerowego
# 2025-12-01 00:49:58,663 [INFO] [239/1400] PUBLISHED: Senior IT Recruitment Consultant | TeamQuest | Warszawa | https://solid.jobs/offer/26183/teamquest-senior-it-recruitment-consultant
# 2025-12-01 00:49:58,731 [INFO] [242/1400] PUBLISHED: MQ Administrator | LeasingTeam Professional | Warszawa | https://solid.jobs/offer/26191/verita-hr-mq-administrator
# 2025-12-01 00:49:58,819 [INFO] [238/1400] PUBLISHED: PC Hardware Expert / Specjalista PC | TeamQuest | Warszawa | https://solid.jobs/offer/26182/teamquest-pc-hardware-expert-specjalista-pc
# 2025-12-01 00:50:00,153 [INFO] [240/1400] PUBLISHED: Specjalista Rekrutacji IT | TeamQuest | Warszawa | https://solid.jobs/offer/26184/teamquest-specjalista-rekrutacji-it
# 2025-12-01 00:50:02,593 [INFO] [241/1400] PUBLISHED: BI / DWH Specialist | Power Media | Katowice | https://solid.jobs/offer/26186/power-media-bi-dwh-specialist
# 2025-12-01 00:50:08,522 [INFO] [245/1400] PUBLISHED: Konsultant Wiodący SAP PP | TeamQuest | Zdalnie | https://solid.jobs/offer/26213/teamquest-konsultant-wiodacy-sap-pp
# 2025-12-01 00:50:09,404 [INFO] [243/1400] PUBLISHED: Azure Architect (short term) | P&P Solutions | Zdalnie | https://solid.jobs/offer/26201/sqaure-one-azure-architect-short-term
# 2025-12-01 00:50:09,820 [INFO] [246/1400] PUBLISHED: Lead SAP PP Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/26214/teamquest-lead-sap-pp-consultant
# 2025-12-01 00:50:10,422 [INFO] [244/1400] PUBLISHED: Spedytor Międzynarodowy | TeamQuest | Zdalnie | https://solid.jobs/offer/26212/teamquest-spedytor-miedzynarodowy
# 2025-12-01 00:50:12,477 [INFO] [247/1400] PUBLISHED: IT Hardware Specialist - Wsparcie i Konfiguracja | TeamQuest | Warszawa | https://solid.jobs/offer/26215/teamquest-it-hardware-specialist-wsparcie-i-konfiguracja
# 2025-12-01 00:50:17,549 [INFO] [248/1400] PUBLISHED: Senior Key Account Manager IT | TeamQuest | Zdalnie | https://solid.jobs/offer/26216/teamquest-senior-key-account-manager-it
# 2025-12-01 00:50:18,570 [INFO] [249/1400] PUBLISHED: Koordynator ds. bezpieczeństwa IT | PTT Consulting | Zdalnie | https://solid.jobs/offer/26218/apreel-koordynator-ds-bezpieczenstwa-it
# 2025-12-01 00:50:20,641 [INFO] [250/1400] PUBLISHED: Fullstack Developer (Java + Angular) | Scalo | Warszawa | https://solid.jobs/offer/26227/scalo-fullstack-developer-java--angular
# 2025-12-01 00:50:22,156 [INFO] [251/1400] PUBLISHED: Senior Node.js & Python Developer | Verita HR | Kraków | https://solid.jobs/offer/26230/verita-hr-senior-nodejs--python-developer
# 2025-12-01 00:50:24,550 [INFO] [252/1400] PUBLISHED: Senior iOS Engineer | HRO Digital/Verita HR | Kraków | https://solid.jobs/offer/26237/verita-hr-senior-ios-engineer
# 2025-12-01 00:50:28,871 [INFO] [253/1400] PUBLISHED: Senior Android Engineer | Verita HR | Kraków | https://solid.jobs/offer/26238/verita-hr-senior-android-engineer
# 2025-12-01 00:50:30,438 [INFO] [254/1400] PUBLISHED: Mid/Senior AEM Engineer | speedapp | Zdalnie | https://solid.jobs/offer/26239/pp-solutions-mid-senior-aem-engineer
# 2025-12-01 00:50:31,770 [INFO] [256/1400] PUBLISHED: Konsultant Wewnętrzny SAP FI/CO | TeamQuest | Środa Wielkopolska | https://solid.jobs/offer/26241/teamquest-konsultant-wewnetrzny-sap-fi-co
# 2025-12-01 00:50:31,865 [INFO] [255/1400] PUBLISHED: Senior Business Analyst | GR8 Solutions | Warszawa | https://solid.jobs/offer/26240/scalo-senior-business-analyst
# 2025-12-01 00:50:37,716 [INFO] [257/1400] PUBLISHED: Dyrektor Sprzedaży (rozwiązania Cloud) | TeamQuest | Warszawa | https://solid.jobs/offer/26252/teamquest-dyrektor-sprzedazy-rozwiazania-cloud
# 2025-12-01 00:50:38,800 [INFO] [259/1400] PUBLISHED: Starszy Konsultant SAP - obszar PP | TeamQuest | Zdalnie | https://solid.jobs/offer/26254/teamquest-starszy-konsultant-sap-obszar-pp
# 2025-12-01 00:50:39,715 [INFO] [261/1400] PUBLISHED: SEO & Ads Specialist | Power Media | Tarnowskie Góry | https://solid.jobs/offer/26280/power-media-seo--ads-specialist
# 2025-12-01 00:50:40,506 [INFO] [258/1400] PUBLISHED: Sales Director (Cloud solutions) | TeamQuest | Warszawa | https://solid.jobs/offer/26253/teamquest-sales-director-cloud-solutions
# 2025-12-01 00:50:43,459 [INFO] [260/1400] PUBLISHED: Software Architect | apreel | Warszawa | https://solid.jobs/offer/26279/apreel-software-architect
# 2025-12-01 00:50:48,563 [INFO] [262/1400] PUBLISHED: Senior Java Developer | Power Media | Katowice | https://solid.jobs/offer/26286/apreel-senior-java-developer
# 2025-12-01 00:50:49,821 [INFO] [265/1400] PUBLISHED: Specjalista Microsoft Dynamics 365 Finance | 1dea | Zdalnie | https://solid.jobs/offer/26304/ptt-consulting-specjalista-microsoft-dynamics-365-finance
# 2025-12-01 00:50:49,906 [INFO] [263/1400] PUBLISHED: Mid/Senior IT Recruiter | TeamQuest | Warszawa | https://solid.jobs/offer/26290/teamquest-mid-senior-it-recruiter
# 2025-12-01 00:50:50,535 [INFO] [264/1400] PUBLISHED: Senior Fullstack Developer | apreel | Warszawa | https://solid.jobs/offer/26299/ptt-consulting-senior-fullstack-developer
# 2025-12-01 00:50:51,085 [INFO] [266/1400] PUBLISHED: SAP HCR Consultant | TeamQuest | Zdalnie | https://solid.jobs/offer/26307/teamquest-sap-hcr-consultant
# 2025-12-01 00:50:55,955 [INFO] [267/1400] PUBLISHED: Konsultant SAP HCM | TeamQuest | Zdalnie | https://solid.jobs/offer/26308/teamquest-konsultant-sap-hcm
# 2025-12-01 00:51:00,057 [INFO] [268/1400] PUBLISHED: Konsultant SAP HCM | TeamQuest | Zdalnie | https://solid.jobs/offer/26309/teamquest-konsultant-sap-hcm
# 2025-12-01 00:51:00,553 [INFO] [269/1400] PUBLISHED: Strategic Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/26316/teamquest-strategic-account-manager
# 2025-12-01 00:51:02,482 [INFO] [271/1400] PUBLISHED: Account Manager | TeamQuest | Łódź | https://solid.jobs/offer/26318/teamquest-account-manager
# 2025-12-01 00:51:03,286 [INFO] [270/1400] PUBLISHED: SAP ABAP Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/26317/teamquest-sap-abap-developer
# 2025-12-01 00:51:07,660 [INFO] [272/1400] PUBLISHED: Senior Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/26319/teamquest-senior-account-manager
# 2025-12-01 00:51:07,733 [INFO] [273/1400] PUBLISHED: Senior Account Manager | TeamQuest | Warszawa | https://solid.jobs/offer/26320/teamquest-senior-account-manager
# 2025-12-01 00:51:11,487 [INFO] [274/1400] PUBLISHED: SQL Application Support Engineer | Devqube | Wrocław | https://solid.jobs/offer/26325/power-media-sql-application-support-engineer
# ...
# 2025-12-01 01:28:41,016 [INFO] [1315/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Gdańsk / Zdalnie | https://solid.jobs/offer/28620/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:43,195 [INFO] [1316/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Gdańsk / Zdalnie | https://solid.jobs/offer/28621/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:44,440 [INFO] [1317/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Gdańsk / Zdalnie | https://solid.jobs/offer/28622/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:48,737 [INFO] [1318/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Gdańsk / Zdalnie | https://solid.jobs/offer/28623/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:55,156 [INFO] [1321/1400] PUBLISHED: Data Engineer | ITFS | Warszawa | https://solid.jobs/offer/28626/amelco-data-engineer
# 2025-12-01 01:28:56,039 [INFO] [1320/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Gdańsk / Zdalnie | https://solid.jobs/offer/28625/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:56,335 [INFO] [1319/1400] PUBLISHED: Field Installation Engineer (Industrial Vision Systems) | Power Media | Katowice / Zdalnie | https://solid.jobs/offer/28624/power-media-field-installation-engineer-industrial-vision-systems
# 2025-12-01 01:28:57,049 [INFO] [1322/1400] PUBLISHED: Scrum Master | apreel | Zdalnie | https://solid.jobs/offer/28627/itp-it-performance-scrum-master
# 2025-12-01 01:29:00,239 [INFO] [1323/1400] PUBLISHED: Scrum Master | ITP IT Performance | Zdalnie | https://solid.jobs/offer/28628/apreel-scrum-master
# 2025-12-01 01:29:04,015 [INFO] [1324/1400] PUBLISHED: Senior CRM Developer (Microsoft Dynamics 365) | TeamQuest | Zdalnie | https://solid.jobs/offer/28629/square-one-resources-senior-crm-developer-microsoft-dynamics-365
# 2025-12-01 01:29:05,285 [INFO] [1327/1400] PUBLISHED: Elektromechanik (K/M) | Paretti | Opole | https://solid.jobs/offer/28632/audit-hr-elektromechanik-k-m
# 2025-12-01 01:29:08,137 [INFO] [1325/1400] PUBLISHED: System - Business Analyst | Scalo | Katowice / Zdalnie | https://solid.jobs/offer/28630/scalo-system-business-analyst
# 2025-12-01 01:29:08,349 [INFO] [1326/1400] PUBLISHED: Algorithm Architect | TeamQuest | Zdalnie | https://solid.jobs/offer/28631/teamquest-algorithm-architect
# 2025-12-01 01:29:11,706 [INFO] [1328/1400] PUBLISHED: IT Rekruter | TeamQuest | Warszawa | https://solid.jobs/offer/28633/click-it-group-it-rekruter
# 2025-12-01 01:29:14,998 [INFO] [1329/1400] PUBLISHED: Senior .NET Developer | Lumicode (Grupa Pentacomp) | Warszawa | https://solid.jobs/offer/28634/lumicode-grupa-pentacomp-senior-dotnet-developer
# 2025-12-01 01:29:15,308 [INFO] [1330/1400] PUBLISHED: Analityk Biznesowy | apreel | Warszawa | https://solid.jobs/offer/28635/apreel-analityk-biznesowy
# 2025-12-01 01:29:21,467 [INFO] [1331/1400] PUBLISHED: DevOps Engineer | apreel | Warszawa | https://solid.jobs/offer/28636/apreel-devops-engineer
# 2025-12-01 01:29:21,852 [INFO] [1332/1400] PUBLISHED: Senior Cloud Data Engineer | P&P Solutions | Zdalnie | https://solid.jobs/offer/28637/itfs-senior-cloud-data-engineer
# 2025-12-01 01:29:23,769 [INFO] [1333/1400] PUBLISHED: Przedstawiciel handlowy (K/M) | Audit HR | Kostrzyn nad Odrą | https://solid.jobs/offer/28638/audit-hr-przedstawiciel-handlowy-k-m
# 2025-12-01 01:29:29,257 [INFO] [1334/1400] PUBLISHED: Specjalista ds. handlu (K/M) | Audit HR | Kostrzyn nad Odrą | https://solid.jobs/offer/28639/audit-hr-specjalista-ds-handlu-k-m
# 2025-12-01 01:29:31,489 [INFO] [1335/1400] PUBLISHED: Starszy Programista Java | Lumicode (Grupa Pentacomp) | Warszawa | https://solid.jobs/offer/28640/lumicode-grupa-pentacomp-starszy-programista-java
# 2025-12-01 01:29:33,000 [INFO] [1336/1400] PUBLISHED: Data Engineer z Power BI | ITFS | Warszawa | https://solid.jobs/offer/28641/click-it-group-data-engineer-z-power-bi
# 2025-12-01 01:29:34,394 [INFO] [1337/1400] PUBLISHED: Senior Computational Geometry Engineer | P&P Solutions | Zdalnie | https://solid.jobs/offer/28642/teamquest-senior-computational-geometry-engineer
# 2025-12-01 01:29:34,725 [INFO] [1338/1400] PUBLISHED: Microsoft SQL Developer | Scalo | Zdalnie | https://solid.jobs/offer/28643/pp-solutions-microsoft-sql-developer
# 2025-12-01 01:29:41,316 [INFO] [1339/1400] PUBLISHED: IT Project Manager (English & Spanish) | Verita HR | Kraków | https://solid.jobs/offer/28644/verita-hr-it-project-manager-english--spanish
# 2025-12-01 01:29:41,969 [INFO] [1340/1400] PUBLISHED: Senior iOS Mobile Developer | 1dea | Zdalnie | https://solid.jobs/offer/28645/1dea-senior-ios-mobile-developer
# 2025-12-01 01:29:44,444 [INFO] [1342/1400] PUBLISHED: AI Specialist | ConnectPoint | Warszawa | https://solid.jobs/offer/28647/itp-it-performance-ai-specialist
# 2025-12-01 01:29:44,530 [INFO] [1341/1400] PUBLISHED: Senior React / Next Developer | TeamQuest | Zdalnie | https://solid.jobs/offer/28646/dev4hire-senior-react-next-developer
# 2025-12-01 01:29:45,661 [INFO] [1343/1400] PUBLISHED: Analityk Biznesowo - Systemowy | P&P Solutions | Warszawa | https://solid.jobs/offer/28648/pp-solutions-analityk-biznesowo-systemowy
# 2025-12-01 01:29:51,093 [INFO] [1344/1400] PUBLISHED: KAM (branża IT) | Audit HR | Gorzów Wielkopolski / Zdalnie | https://solid.jobs/offer/28649/gr8-solutions-kam-branza-it
# 2025-12-01 01:29:53,320 [INFO] [1345/1400] PUBLISHED: Asystent ds. Sprzedaży i Rozwoju Klienta | TeamQuest | Warszawa | https://solid.jobs/offer/28650/teamquest-asystent-ds-sprzedazy-i-rozwoju-klienta
# 2025-12-01 01:29:55,308 [INFO] [1347/1400] PUBLISHED: Data Engineer | Next Technology Professionals | Zdalnie | https://solid.jobs/offer/28652/scalo-data-engineer
# 2025-12-01 01:29:56,549 [INFO] [1346/1400] PUBLISHED: Główny Księgowy / Główna Księgowa | TeamQuest | Zdalnie | https://solid.jobs/offer/28651/taptalent-glowny-ksiegowy-glowna-ksiegowa
# 2025-12-01 01:29:56,878 [INFO] [1348/1400] PUBLISHED: Java / Kotlin Developer | apreel | Warszawa / Zdalnie | https://solid.jobs/offer/28653/apreel-java-kotlin-developer
# 2025-12-01 01:30:01,617 [INFO] [1349/1400] PUBLISHED: Mid Java Developer | BrainForge IT Software & Consulting | Zdalnie | https://solid.jobs/offer/28654/apreel-mid-java-developer
# 2025-12-01 01:30:03,515 [INFO] [1350/1400] PUBLISHED: Analityk RPA | apreel | Zdalnie | https://solid.jobs/offer/28655/apreel-analityk-rpa
# 2025-12-01 01:30:07,360 [INFO] [1353/1400] PUBLISHED: Specjalista ds. marketingu (K/M) | TeamQuest | Poznań | https://solid.jobs/offer/28658/audit-hr-specjalista-ds-marketingu-k-m
# 2025-12-01 01:30:07,614 [INFO] [1351/1400] PUBLISHED: Specjalista / ka ds. Eksportu (angielski + rosyjski / ukraiński) | HR Partner Consulting | Płock | https://solid.jobs/offer/28656/hr-partner-consulting-specjalista-ka-ds-eksportu-angielski--rosyjski-ukrainski
# 2025-12-01 01:30:07,777 [INFO] [1352/1400] PUBLISHED: Export Manager (ukraiński / rosyjski) | HR Partner Consulting | Płock | https://solid.jobs/offer/28657/hr-partner-consulting-export-manager-ukrainski-rosyjski
# 2025-12-01 01:30:12,148 [INFO] [1354/1400] PUBLISHED: Mainframe DevOps (German) | Scalo | Łódź | https://solid.jobs/offer/28659/click-it-group-mainframe-devops-german
# 2025-12-01 01:30:13,150 [INFO] [1357/1400] PUBLISHED: Ekspert / Ekspertka ds. taryfikacji ubezpieczeń komunikacyjnych | Power Media | Katowice | https://solid.jobs/offer/28662/aneta-biadun-italent--hr-partner-ekspert-ekspertka-ds-taryfikacji-ubezpieczen-komunikacyjnych
# 2025-12-01 01:30:16,888 [INFO] [1355/1400] PUBLISHED: Senior Java Software Engineer | Power Media | Katowice | https://solid.jobs/offer/28660/power-media-senior-java-software-engineer
# 2025-12-01 01:30:18,975 [INFO] [1356/1400] PUBLISHED: Java Software Engineer | Power Media | Katowice | https://solid.jobs/offer/28661/power-media-java-software-engineer
# 2025-12-01 01:30:19,846 [INFO] [1358/1400] PUBLISHED: Data Architect / Technical Lead (Informatica) | Power Media | Katowice | https://solid.jobs/offer/28663/power-media-data-architect-technical-lead-informatica
# 2025-12-01 01:30:22,254 [INFO] [1359/1400] PUBLISHED: Data Architect / Technical Lead (Informatica) | Verita HR | Kraków | https://solid.jobs/offer/28664/power-media-data-architect-technical-lead-informatica
# 2025-12-01 01:30:23,974 [INFO] [1360/1400] PUBLISHED: Data Architect / Technical Lead (Informatica) | Click IT Group | Zdalnie | https://solid.jobs/offer/28665/power-media-data-architect-technical-lead-informatica
# 2025-12-01 01:30:27,433 [INFO] [1361/1400] PUBLISHED: Młodszy / a Specjalista / ka ds. obsługi klienta | TeamQuest | Warszawa | https://solid.jobs/offer/28666/hr-partner-consulting-mlodszy-a-specjalista-ka-ds-obslugi-klienta
# 2025-12-01 01:30:30,320 [INFO] [1363/1400] PUBLISHED: Junior Java Developer | BrainForge IT Software & Consulting | Zdalnie | https://solid.jobs/offer/28668/apreel-junior-java-developer
# 2025-12-01 01:30:30,493 [INFO] [1362/1400] PUBLISHED: Product Manager (Visa / Mastercard) | TeamQuest | Warszawa | https://solid.jobs/offer/28667/1dea-product-manager-visa-mastercard
# 2025-12-01 01:30:33,137 [INFO] [1364/1400] PUBLISHED: Projektant HVAC / Wod-Kan | FERCHAU Poland | Zdalnie | https://solid.jobs/offer/28669/ferchau-poland-projektant-hvac-wodkan
# 2025-12-01 01:30:34,052 [INFO] [1365/1400] PUBLISHED: Asystent Projektanta HVAC / Wod-Kan | FERCHAU Poland | Zdalnie | https://solid.jobs/offer/28670/ferchau-poland-asystent-projektanta-hvac-wodkan
# 2025-12-01 01:30:38,425 [INFO] [1366/1400] PUBLISHED: Backend Golang Developer | ITFS | Zdalnie | https://solid.jobs/offer/28672/elektroniczne-systemy-sprzedazy-backend-golang-developer
# 2025-12-01 01:30:40,132 [INFO] [1367/1400] PUBLISHED: Go System - Level Developer | ITFS | Zdalnie | https://solid.jobs/offer/28673/square-one-resources-go-system-level-developer
# 2025-12-01 01:30:41,005 [INFO] [1368/1400] PUBLISHED: Java Developer | P&P Solutions | Zdalnie | https://solid.jobs/offer/28674/infolet-java-developer
# 2025-12-01 01:30:42,461 [INFO] [1369/1400] PUBLISHED: Angular Developer | apreel | Zdalnie | https://solid.jobs/offer/28675/apreel-angular-developer
# 2025-12-01 01:30:43,939 [INFO] [1370/1400] PUBLISHED: Angular Developer | apreel | Zdalnie | https://solid.jobs/offer/28676/apreel-angular-developer
# 2025-12-01 01:30:49,357 [INFO] [1371/1400] PUBLISHED: Angular Developer | apreel | Zdalnie | https://solid.jobs/offer/28677/apreel-angular-developer
# 2025-12-01 01:30:50,626 [INFO] [1373/1400] PUBLISHED: Analityk AML | apreel | Zdalnie | https://solid.jobs/offer/28679/speedapp-analityk-aml
# 2025-12-01 01:30:50,721 [INFO] [1372/1400] PUBLISHED: Fullstack JavaScript Developer | speedapp | Zdalnie | https://solid.jobs/offer/28678/ascendix-fullstack-javascript-developer
# 2025-12-01 01:30:51,469 [INFO] [1374/1400] PUBLISHED: Technical Integration Manager | TeamQuest | Zdalnie | https://solid.jobs/offer/28680/1dea-technical-integration-manager
# 2025-12-01 01:30:54,348 [INFO] [1375/1400] PUBLISHED: AI/ML Engineer | Alcor | Zdalnie | https://solid.jobs/offer/28681/orto-algorytmics-ai-ml-engineer
# 2025-12-01 01:31:01,618 [INFO] [1376/1400] PUBLISHED: iOS Swift Developer | Verita HR | Kraków | https://solid.jobs/offer/28682/orto-algorytmics-ios-swift-developer
# 2025-12-01 01:31:02,617 [INFO] [1378/1400] PUBLISHED: Operations & Automation Specialist | P&P Solutions | Zdalnie | https://solid.jobs/offer/28684/alcor-operations--automation-specialist
# 2025-12-01 01:31:02,871 [INFO] [1379/1400] PUBLISHED: React Developer (C++) | TeamQuest | Zdalnie | https://solid.jobs/offer/28685/teamquest-react-developer-cplusplus
# 2025-12-01 01:31:03,040 [INFO] [1377/1400] PUBLISHED: ML & Simulation Engineer | Verita HR | Kraków | https://solid.jobs/offer/28683/orto-algorytmics-ml--simulation-engineer
# 2025-12-01 01:31:08,979 [INFO] [1380/1400] PUBLISHED: Programista React (C++) | TeamQuest | Zdalnie | https://solid.jobs/offer/28686/teamquest-programista-react-cplusplus
# 2025-12-01 01:31:12,308 [INFO] [1381/1400] PUBLISHED: Business - System Analyst | Scalo | Zdalnie | https://solid.jobs/offer/28687/scalo-business-system-analyst
# 2025-12-01 01:31:14,795 [INFO] [1382/1400] PUBLISHED: Data Engineer | apreel | Zdalnie | https://solid.jobs/offer/28688/itfs-data-engineer
# 2025-12-01 01:31:15,597 [INFO] [1383/1400] PUBLISHED: Java Developer | Scalo | Zdalnie | https://solid.jobs/offer/28689/scalo-java-developer
# 2025-12-01 01:31:17,490 [INFO] [1384/1400] PUBLISHED: DevOps Engineer | Scalo | Katowice / Zdalnie | https://solid.jobs/offer/28690/scalo-devops-engineer
# 2025-12-01 01:31:20,424 [INFO] [1385/1400] PUBLISHED: Digital Sales Manager | GoRecruitment | Warszawa | https://solid.jobs/offer/28691/gorecruitment-digital-sales-manager
# 2025-12-01 01:31:24,046 [INFO] [1387/1400] PUBLISHED: Analityk Systemowy | Lumicode (Grupa Pentacomp) | Zdalnie | https://solid.jobs/offer/28693/lumicode-grupa-pentacomp-analityk-systemowy
# 2025-12-01 01:31:24,860 [INFO] [1386/1400] PUBLISHED: Field Test Engineer | TeamQuest | Warszawa | https://solid.jobs/offer/28692/infolet-field-test-engineer
# 2025-12-01 01:31:26,182 [INFO] [1388/1400] PUBLISHED: Specjalista ds. wsparcia IT (K/M) | Ascendix | Zdalnie | https://solid.jobs/offer/28694/audit-hr-specjalista-ds-wsparcia-it-k-m
# 2025-12-01 01:31:26,831 [INFO] [1389/1400] PUBLISHED: Fullstack Engineer .NET / C# | Scalo | Kraków | https://solid.jobs/offer/28695/verita-hr-fullstack-engineer-dotnet-csharp
# 2025-12-01 01:31:31,079 [INFO] [1390/1400] PUBLISHED: Senior Test Engineer / QA Lead | Verita HR | Kraków | https://solid.jobs/offer/28696/verita-hr-senior-test-engineer-qa-lead
# 2025-12-01 01:31:37,252 [INFO] [1391/1400] PUBLISHED: Java Developer | apreel | Warszawa | https://solid.jobs/offer/28697/speedapp-java-developer
# 2025-12-01 01:31:38,617 [INFO] [1392/1400] PUBLISHED: Specjalista ds. zarządzania i bezpieczeństwa sieciowego (K/M) | P&P Solutions | Zdalnie | https://solid.jobs/offer/28698/audit-hr-specjalista-ds-zarzadzania-i-bezpieczenstwa-sieciowego-k-m
# 2025-12-01 01:31:40,211 [INFO] [1393/1400] PUBLISHED: Java Developer | apreel | Warszawa | https://solid.jobs/offer/28699/itfs-java-developer
# 2025-12-01 01:31:40,675 [INFO] [1394/1400] PUBLISHED: Senior Java Developer | Lumicode (Grupa Pentacomp) | Warszawa | https://solid.jobs/offer/28700/lumicode-grupa-pentacomp-senior-java-developer
# 2025-12-01 01:31:43,516 [INFO] [1395/1400] PUBLISHED: Lead Frontend Developer | Scalo | Warszawa | https://solid.jobs/offer/28701/1dea-lead-frontend-developer
# 2025-12-01 01:31:45,824 [INFO] [1396/1400] PUBLISHED: Murex Integration Consultant / Konsultant ds.Integracji Murex | 1dea | Warszawa / Zdalnie | https://solid.jobs/offer/28702/1dea-murex-integration-consultant-konsultant-dsintegracji-murex
# 2025-12-01 01:31:49,060 [INFO] [1397/1400] PUBLISHED: Senior Frontend Developer | Lumicode (Grupa Pentacomp) | Warszawa | https://solid.jobs/offer/28703/lumicode-grupa-pentacomp-senior-frontend-developer
# 2025-12-01 01:31:49,251 [INFO] [1398/1400] PUBLISHED: Tester manualny (mid) | apreel | Warszawa | https://solid.jobs/offer/28704/lumicode-grupa-pentacomp-tester-manualny-mid
# 2025-12-01 01:31:50,826 [INFO] [1399/1400] PUBLISHED: Java Developer | P&P Solutions | Zdalnie | https://solid.jobs/offer/28705/lumicode-grupa-pentacomp-java-developer
# 2025-12-01 01:31:52,845 [INFO] [1400/1400] PUBLISHED: Сustomer Support Specialist | Infolet | Warszawa | https://solid.jobs/offer/28706/ascendix-ustomer-support-specialist
# 2025-12-01 01:31:53,555 [INFO] --- SCRAPING FINISHED ---
# 2025-12-01 01:31:53,556 [INFO] Offers successfully published to Pub/Sub: 1399
# 2025-12-01 01:31:53,556 [INFO] Offers with fetch errors: 1
# 2025-12-01 01:31:53,557 [INFO] Exec time: 2957.97 s (~49.3 min)
# 2025-12-01 01:31:53,558 [INFO] Saved logs to: solid_jobs_log_20251201_004055.log
